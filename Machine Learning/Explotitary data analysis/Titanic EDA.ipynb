# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Datasets/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# sns.countplot(df['Embarked'])
# #df['Survived'].value_counts().plot(kind='bar')

# %%
sns.countplot(df, x="Survived")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# Pie Chart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [raw]
# histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=40)
# Out:
# (array([24., 16.,  7.,  7., 10.,  5.,  8., 23., 39., 40., 52., 46., 42.,
#         43., 47., 37., 32., 41., 18., 27., 21., 14., 17., 18., 16., 13.,
#          9.,  7.,  7.,  6.,  7.,  4.,  4.,  0.,  2.,  3.,  1.,  0.,  0.,
#          1.]),
#  array([ 0.42  ,  2.4095,  4.399 ,  6.3885,  8.378 , 10.3675, 12.357 ,
#         14.3465, 16.336 , 18.3255, 20.315 , 22.3045, 24.294 , 26.2835,
#         28.273 , 30.2625, 32.252 , 34.2415, 36.231 , 38.2205, 40.21  ,
#         42.1995, 44.189 , 46.1785, 48.168 , 50.1575, 52.147 , 54.1365,
#         56.126 , 58.1155, 60.105 , 62.0945, 64.084 , 66.0735, 68.063 ,
#         70.0525, 72.042 , 74.0315, 76.021 , 78.0105, 80.    ]),
#  <BarContainer object of 40 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16704\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
iris = pd.read_csv('Datasets/iris.csv')

# %%
tips = pd.read_csv('Datasets/tip.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue= 'sex',style= 'smoker',size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data = df,x = 'Pclass',y = 'Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data = df,x = 'Sex',y = 'Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16704\455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16704\455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
 (df.groupby('Pclass')['Survived'].mean()*100)
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
sns.clustermap(pd.crosstab(df['SibSp'],df['Survived']))

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(iris,hue='Species')

# %%
batter = pd.read_csv('Datasets/diabetes (1).csv')
batter
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.countplot(data=batter , x='Outcome')
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
batter['Outcome'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(batter['BloodPressure'],bins=30)
# Out:
# (array([ 35.,   0.,   0.,   0.,   0.,   1.,   0.,   2.,   0.,   2.,   4.,
#           7.,  24.,  25.,  58.,  85.,  75., 101.,  99.,  85.,  59.,  46.,
#          30.,  11.,   6.,   3.,   5.,   3.,   1.,   1.]),
#  array([  0.        ,   4.06666667,   8.13333333,  12.2       ,
#          16.26666667,  20.33333333,  24.4       ,  28.46666667,
#          32.53333333,  36.6       ,  40.66666667,  44.73333333,
#          48.8       ,  52.86666667,  56.93333333,  61.        ,
#          65.06666667,  69.13333333,  73.2       ,  77.26666667,
#          81.33333333,  85.4       ,  89.46666667,  93.53333333,
#          97.6       , 101.66666667, 105.73333333, 109.8       ,
#         113.86666667, 117.93333333, 122.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.distplot(batter['SkinThickness'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16704\1632341475.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(batter['SkinThickness'])
# <Axes: xlabel='SkinThickness', ylabel='Density'>

# %%
sns.boxplot(batter['BloodPressure'])
# Out:
# <Axes: ylabel='BloodPressure'>

# %%
batter.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
patient = pd.read_csv("Datasets/gathering/patients.csv")

# %%
patient.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
sns.scatterplot(data=patient,x='weight',y='height',hue='assigned_sex',size='bmi',style='assigned_sex')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %%
sns.barplot(data=patient,x='assigned_sex',y = 'bmi')
# Out:
# <Axes: xlabel='assigned_sex', ylabel='bmi'>

# %%
sns.boxplot(data=patient,x='assigned_sex',y = 'bmi')
# Out:
# <Axes: xlabel='assigned_sex', ylabel='bmi'>

# %%
sns.distplot(patient['bmi'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16704\2601434669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(patient['bmi'])
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
