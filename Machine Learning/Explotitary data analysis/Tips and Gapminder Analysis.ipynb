# %%
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px

# %%
gap=px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.lineplot(data = gap,x='year',y='lifeExp')
plt.title("Year vs LifeExp")
plt.show()

# %%
sns.relplot(data=gap,x='year',y='lifeExp',kind='line')
plt.title("Year vs LifeExp")
plt.show()

# %%
temp_df = gap[gap['country'].isin(['India','Pakistan','China'])]
temp_df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.relplot(kind='line',data=temp_df,x='year',y='lifeExp',hue='country')
plt.title('Year vs LifeExp')
plt.show()

# %%
sns.lineplot(data=temp_df,x='year',y='lifeExp',hue='country')
plt.show()

# %%
sns.scatterplot(data=gap,x='country',y='gdpPercap',hue='continent')
plt.show()

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=3)
plt.show()

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=3,hue='country')
plt.show()

# %%
sns.histplot(data=gap,x='lifeExp')
plt.show()

# %%
#Kernal density estimation (smooths a plot with a gausian kernal)
sns.kdeplot(data=gap,x='iso_num')
plt.show()

# %%
sns.displot(data=gap,x='iso_num',kind='kde')
plt.show()

# %%
#Rugplot
sns.rugplot(data=gap,x='iso_num')
plt.show()

# %%
gap.sample(10)
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 935        Malawi    Africa  2007   48.303  13327079   759.349910       MWI
# 159      Botswana    Africa  1967   53.298    553541  1214.709294       BWA
# 1576       Turkey    Europe  1972   57.005  37492953  3450.696380       TUR
# 1393      Somalia    Africa  1957   34.977   2780415  1258.147413       SOM
# 40         Angola    Africa  1972   37.928   5894858  5473.288005       AGO
# 1653      Vietnam      Asia  1997   70.672  76048996  1385.896769       VNM
# 125         Benin    Africa  1977   49.190   3168267  1029.161251       BEN
# 449       Ecuador  Americas  1977   61.310   7278866  6679.623260       ECU
# 1674  Yemen, Rep.      Asia  1982   49.113   9657618  1977.557010       YEM
# 962    Mauritania    Africa  1962   44.248   1146757  1055.896036       MRT
#
#       iso_num
# 935       454
# 159        72
# 1576      792
# 1393      706
# 40         24
# 1653      704
# 125       204
# ...

# %%
#Heat Map'
temp_df = gap.pivot(index='country',columns='year',values='lifeExp')
temp_df.head()
# Out:
# year           1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Afghanistan  28.801  30.332  31.997  34.020  36.088  38.438  39.854  40.822
# Albania      55.230  59.280  64.820  66.220  67.690  68.930  70.420  72.000
# Algeria      43.077  45.685  48.303  51.407  54.518  58.014  61.368  65.799
# Angola       30.015  31.999  34.000  35.985  37.928  39.483  39.942  39.906
# Argentina    62.485  64.399  65.142  65.634  67.065  68.481  69.942  70.774
#
# year           1992    1997    2002    2007
# country
# Afghanistan  41.674  41.763  42.129  43.828
# Albania      71.581  72.950  75.651  76.423
# Algeria      67.744  69.152  70.994  72.301
# Angola       40.647  40.963  41.003  42.731
# Argentina    71.868  73.275  74.340  75.320

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp_df)
plt.show()

# %%
temp_df= gap[gap['continent'] == 'Europe'].pivot(index='country',columns='year',values='lifeExp')
temp_df
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp_df,annot=True,linewidth=5)
plt.show()

# %%
temp_df_asia = gap[gap['continent'] == 'Asia'].pivot(index='country',columns='year',values='lifeExp')
temp_df_asia.head()
# Out:
# year           1952      1957      1962      1967      1972      1977    1982  \
# country
# Afghanistan  28.801  30.33200  31.99700  34.02000  36.08800  38.43800  39.854
# Bahrain      50.939  53.83200  56.92300  59.92300  63.30000  65.59300  69.052
# Bangladesh   37.484  39.34800  41.21600  43.45300  45.25200  46.92300  50.009
# Cambodia     39.417  41.36600  43.41500  45.41500  40.31700  31.22000  50.957
# China        44.000  50.54896  44.50136  58.38112  63.11888  63.96736  65.525
#
# year           1987    1992    1997    2002    2007
# country
# Afghanistan  40.822  41.674  41.763  42.129  43.828
# Bahrain      70.750  72.601  73.925  74.795  75.635
# Bangladesh   52.819  56.018  59.412  62.013  64.062
# Cambodia     53.914  55.803  56.534  56.752  59.723
# China        67.274  68.690  70.426  72.028  72.961

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp_df,annot=True,linewidth=5)
plt.show()

# %%
#cluster map(plot as hirerachically clustered heatmap)
iris= px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])
plt.show()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#strip plot
sns.stripplot(data=tips,x='day',y='total_bill',jitter=False)
plt.show()

# %%
sns.catplot(data = tips,x='day',y='total_bill',kind='strip')
plt.show()

# %%
sns.catplot(data = tips,x='day',y='total_bill',kind='strip',jitter=1)
plt.show()

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='swarm',hue='sex')
plt.show()

# %%
#BOX plot
sns.boxplot(data=tips,x='day',y='total_bill')
plt.show()

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='box',hue='sex')
plt.show()

# %%
sns.boxplot(data=tips,y='total_bill')
plt.show()

# %%
#violin in plot
sns.violinplot(data=tips,x='day',y='total_bill')
plt.show()

# %%
#barplot
import numpy as np
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker',estimator=np.std)
plt.show()

# %%
sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker')
plt.show()

# %%
#count plot
sns.countplot(data=tips,x='sex')
plt.show()

# %%
sns.regplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')
plt.show()

# %%
sns.residplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.catplot(data=tips,x='sex',y='total_bill',kind='violin',col='day')
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")
plt.show()

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill")
plt.show()

# %%
g = sns.FacetGrid(tips, col="time", row="sex")
g.map_dataframe(sns.histplot, x="total_bill", binwidth=2, binrange=(0, 60))
plt.show()

# %%
g = sns.FacetGrid(tips, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip", hue="sex")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(tips, col="day", height=3.5, aspect=.65)
g.map(sns.histplot, "total_bill")
plt.show()

# %%
g = sns.FacetGrid(tips, col="size", height=2.5, col_wrap=3)
g.map(sns.histplot, "total_bill")
plt.show()

# %%
g = sns.FacetGrid(tips, col="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.refline(y=tips["tip"].median())
plt.show()

# %%
import matplotlib.pyplot as plt
def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.map_dataframe(annotate)
plt.show()

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill ($)", "Tip ($)")
g.set_titles(col_template="{col_name} patrons", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout()
g.savefig("facet_plot.png")
plt.show()

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=False)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0))
plt.show()
